# %% [markdown]
# Created by Junyeong Ahn.

# %% [markdown]
# ## Welcome to [USACO](https://usaco.org/) [Silver] course!

# %% [markdown]
# ### Contest Schedule

# %% [markdown]
# First contest - December
#
# Second contest - January
#
# Third contest - February
#
# US open - March

# %% [markdown]
# In each class,
#
# 40 minutes: Feedback for your assignment
# - Not to exceed this expected time taken, please always be well-prepared with your assignment, including being ready for code review and (of course) doing your best.
#
# 60 minutes: Solve 1 problem
#
# 15 minutes: Wrap-up, dealing with the keys behind the soluiton
#
# <br><br>
# Assignment: 3 problems - Try to solve one problem in every two days

# %% [markdown]
# ## Problem

# %% [markdown]
# Note 1: You must be aware of how to use 'sys.stdin.readline'!

# %% [markdown]
# Note 2: To validate your answer, run the following commands in terminal.
#
# Suppose your current working location is ...../usaco/bronze/homework/2021-2022/sleeping-in-class ,
#
# ```
# python3 PROBLEM_NAME.py < ./testers/x.in > ./testers/my_x.out
# ```
#
# ```
# diff ./testers/my_x.out ./testers/x.out
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Note 3: To download such testing files,

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Note 4: To make use of Note 2,
# - Create a separate ```.py``` for each solution. <u>Your tutor will let you know how to construct the file tree</u>.
# - Place your solution ```.py``` file and the testing files (```x.in``` and ```x.out```) in the same folder (your current workspace in most cases).

# %% [markdown]
# USACO 2021 Dec. Silver Problem 1. [Closest Cow Wins](https://usaco.org/index.php?page=viewproblem2&cpid=1158)

# %%
# Solution

# %% [markdown]
# ## Homework

# %% [markdown]
# USACO 2021 Dec. Silver Problem 2. [Connecting Two Brains](https://usaco.org/index.php?page=viewproblem2&cpid=1159)

# %%
# Solution
def solve():

    ...

if __name__ == "__main__":
    solve()

# %% [markdown]
# USACO 2021 Dec. Silverr Problem 3. [Convoluted Intervals](https://usaco.org/index.php?page=viewproblem2&cpid=1160)

# %%
# Solution
# Now you know how the template looks like!
