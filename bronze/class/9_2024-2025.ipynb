# %% [markdown]
# Created by Junyeong Ahn.

# %% [markdown]
# ## Welcome to [USACO](https://usaco.org/) [Bronze] course!

# %% [markdown]
# ### Contest Schedule

# %% [markdown]
# First contest - December
#
# Second contest - January
#
# Third contest - February
#
# US open - March

# %% [markdown]
# ### Class Schedule

# %% [markdown]
# 2025. 09: 2021-2022 (Feb for class, the rest for HW)
# 2025. 10: 2022-2023 (Feb for class, the rest for HW)
# 2025. 11: 2023-2024 (Feb for class, the rest for HW)
# 2025. 12: 2024-2025 (Feb for class, the rest for HW)

# %% [markdown]
# In each class,
#
# 15 minutes: Implementation test for one random quesiton
#
# 45 minutes: Homework feedback session
#
# 60 minutes: Solve 1 problem (Live coding guidance)
#
# <br><br>
# Assignment: Review two problems & solve one problem.
# If you fail to solve the problem during class, it becomes your additional homework!

# %% [markdown]
# ## Problem

# %% [markdown]
# USACO 2024 Dec. Bronze Problem 3. [It's Mooin' Time](https://usaco.org/index.php?page=viewproblem2&cpid=1445)

# %% [markdown]
# *Do you remember this problem?

# %%
# Solution

# %% [markdown]
# ## Homework

# %% [markdown]
# ### Commenting & Implementation Test Preperation

# %% [markdown]
# USACO 2025 US Open Bronze Problem 3. [It's Mooin' Time III](https://usaco.org/index.php?page=viewproblem2&cpid=1517)

# %%
# Solution

# %% [markdown]
# USACO 2025 Feb. Bronze Problem 3. [Printing Sequences](https://usaco.org/index.php?page=viewproblem2&cpid=1493)

# %%
# Solution

# %% [markdown]
# ### Problems to Solve

# %% [markdown]
# USACO 2025 Jan. Bronze Problem 3. [Cow Checkups](https://usaco.org/index.php?page=viewproblem2&cpid=1469)

# %%
# Solution
